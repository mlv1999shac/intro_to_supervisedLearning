# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("telecom_churn.csv")
data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# 6       MA             121        510                 No             Yes
# 7       MO             147        415                Yes              No
# 8       LA             117        408                 No              No
# 9       WV             141        415                Yes             Yes
# 10      IN              65        415                 No              No
# 11      RI              74        415                 No              No
# ...

# %%
data.columns[0]
# Out:
# 'State'

# %%
data['State']
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
# 5       AL
# 6       MA
# 7       MO
# 8       LA
# 9       WV
# 10      IN
# 11      RI
# 12      IA
# 13      MT
# 14      IA
# 15      NY
# 16      ID
# 17      VT
# 18      VA
# 19      TX
# 20      FL
# 21      CO
# 22      AZ
# 23      SC
# 24      VA
# 25      NE
# 26      WY
# 27      MT
# 28      MO
# 29      HI
#         ..
# 3303    WI
# 3304    IL
# 3305    IN
# 3306    AL
# 3307    OK
# 3308    IA
# 3309    VT
# 3310    NY
# 3311    LA
# 3312    SC
# 3313    ID
# 3314    MO
# 3315    ME
# 3316    MS
# 3317    SD
# 3318    OK
# 3319    WY
# 3320    GA
# 3321    VT
# 3322    MD
# 3323    IN
# 3324    WV
# 3325    OH
# 3326    OH
# 3327    SC
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data['Churn']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10       True
# 11      False
# 12      False
# 13      False
# 14      False
# 15       True
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21       True
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3303    False
# 3304     True
# 3305    False
# 3306    False
# 3307    False
# 3308    False
# 3309    False
# 3310    False
# 3311    False
# 3312    False
# 3313    False
# 3314    False
# 3315    False
# 3316    False
# 3317    False
# 3318    False
# 3319    False
# 3320     True
# 3321    False
# 3322     True
# 3323     True
# 3324    False
# 3325    False
# 3326    False
# 3327    False
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# ...

# %%
data['Customer service calls'].value_counts()
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: Customer service calls, dtype: int64

# %%
data['Customer service calls' ].mean()
# Out:
# 1.5628562856285628

# %%
data['Churn' ].mean()
# Out:
# 0.14491449144914492

# %%
data['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
data[data['Customer service calls'] == 1 ]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 8       LA             117        408                 No              No
# 12      IA             168        408                 No              No
# 16      ID              85        408                 No             Yes
# 18      VA              76        510                 No             Yes
# 19      TX              73        415                 No              No
# 29      HI              49        510                 No              No
# 31      NH              75        510                 No              No
# 33      AZ              12        408                 No              No
# 37      MA              78        415                 No              No
# 39      NJ             149        408                 No              No
# ...

# %%
data['State'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-35c14994d8cb> in <module>()
# ----> 1 data['State'][0]
#
# NameError: name 'data' is not defined

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data[['State','Churn','Area code']]
# Out:
#      State  Churn  Area code
# 0       KS  False        415
# 1       OH  False        415
# 2       NJ  False        415
# 3       OH  False        408
# 4       OK  False        415
# 5       AL  False        510
# 6       MA  False        510
# 7       MO  False        415
# 8       LA  False        408
# 9       WV  False        415
# 10      IN   True        415
# 11      RI  False        415
# 12      IA  False        408
# 13      MT  False        510
# 14      IA  False        415
# 15      NY   True        415
# 16      ID  False        408
# 17      VT  False        510
# 18      VA  False        510
# 19      TX  False        415
# 20      FL  False        415
# 21      CO   True        408
# 22      AZ  False        415
# 23      SC  False        415
# 24      VA  False        510
# 25      NE  False        415
# 26      WY  False        408
# 27      MT  False        408
# 28      MO  False        415
# 29      HI  False        510
# ...    ...    ...        ...
# ...

# %%
data[ data['Churn'] == True].mean()
# Out:
# State                      55.204969
# Account length             55.204969
# Area code                  55.204969
# International plan         55.204969
# Voice mail plan            55.204969
# Number vmail messages      55.204969
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
data.loc[:, 'State': 'International plan']
# Out:
#      State  Account length  Area code International plan
# 0       KS             128        415                 No
# 1       OH             107        415                 No
# 2       NJ             137        415                 No
# 3       OH              84        408                Yes
# 4       OK              75        415                Yes
# 5       AL             118        510                Yes
# 6       MA             121        510                 No
# 7       MO             147        415                Yes
# 8       LA             117        408                 No
# 9       WV             141        415                Yes
# 10      IN              65        415                 No
# 11      RI              74        415                 No
# 12      IA             168        408                 No
# 13      MT              95        510                 No
# 14      IA              62        415                 No
# ...

# %%
data[ data['Customer service calls'] == 1 ].loc[:, "Total intl minutes":"Churn" ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-6defd7c6be0b> in <module>()
# ----> 1 data[ data['Customer service calls'] == 1 ].loc[:, "Total intl minutes":"Churn" ].value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
data[ data['Customer service calls'] == 1 ][ "Churn" ].value_counts()
# Out:
# False    1059
# True      122
# Name: Churn, dtype: int64

# %%
data[ data['Churn'] == True ]['Total day minutes'].mean()
# Out:
# 206.91407867494814

# %%
data.head(1)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                       1  False

# %%
data[ data['International plan'] == 'No'][ data['Churn'] == 0 ]['Total intl minutes'].max()
# Out:
# C:\Users\mahidhai\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 18.9

# %%
data[ data['Total intl minutes'] == 18.9 ]
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 314    ID             128        408                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 314                      0              125.2               99
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 314             21.28              205.4              107             17.46
#
#      Total night minutes  Total night calls  Total night charge  \
# 314                254.4                111               11.45
#
#      Total intl minutes  Total intl calls  Total intl charge  \
# 314                18.9                 2                5.1
#
#      Customer service calls  Churn
# 314                       0  False

# %%
data.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes         395
# Total night calls           175
# Total night charge        17.77
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                      True
# dtype: object

# %%
data.max()
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes         395
# Total night calls           175
# Total night charge        17.77
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                      True
# dtype: object

# %%
data['Total intl calls'].max()
# Out:
# 20

# %%
data.loc[1]
# Out:
# State                        OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls             123
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls             103
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls           103
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls        1
# Churn                     False
# Name: 1, dtype: object

# %%
data[ 'State']

# %%
data.iloc[1]
# Out:
# State                        OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls             123
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls             103
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls           103
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls        1
# Churn                     False
# Name: 1, dtype: object

# %%
data.iloc[1]
# Out:
# State                        OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls             123
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls             103
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls           103
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls        1
# Churn                     False
# Name: 1, dtype: object

# %%
d = { 'Yes' : 'Y' , 'No' : 'n'}
data['International plan'] = data['International plan'].map(d)
data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                  n             Yes
# 1       OH             107        415                  n             Yes
# 2       NJ             137        415                  n              No
# 3       OH              84        408                  Y              No
# 4       OK              75        415                  Y              No
# 5       AL             118        510                  Y              No
# 6       MA             121        510                  n             Yes
# 7       MO             147        415                  Y              No
# 8       LA             117        408                  n              No
# 9       WV             141        415                  Y             Yes
# 10      IN              65        415                  n              No
# 11      RI              74        415                  n              No
# ...

# %%
d = { 'Y' : 'Yes' , 'n' : 'No'}
data['International plan'] = data['International plan'].map(d)
data.head(1)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                       1  False

# %%
# homework
#replace all the data whose value is less than 10 with 1 , less than 20 and greter than 10 with 2

#replace all values les than 10 to 0 and greater than 50 to 50 -apporximation

# %%
#groupby
#df.groupby(by=grouping_columns)[columns_to_show].function()
columns_to_show = ['Total day minutes', 'Total eve minutes','Total night minutes']
data.groupby(['Churn'])[columns_to_show].describe(percentiles=[])

# %%
data[ ['Total day minutes', 'Total eve minutes','Total night minutes']].describe(percentiles=[])
# Out:
#        Total day minutes  Total eve minutes  Total night minutes
# count        3333.000000        3333.000000          3333.000000
# mean          179.775098         200.980348           200.872037
# std            54.467389          50.713844            50.573847
# min             0.000000           0.000000            23.200000
# 50%           179.400000         201.400000           201.200000
# max           350.800000         363.700000           395.000000

# %%
data.groupby(['Churn'])['Total day minutes', 'Total eve minutes','Total night minutes'].describe()
# Out:
#       Total day minutes                                                      \
#                   count        mean        std  min      25%    50%     75%
# Churn
# False            2850.0  175.175754  50.181655  0.0  142.825  177.2  210.30
# True              483.0  206.914079  68.997792  0.0  153.250  217.6  265.95
#
#              Total eve minutes              ...                   \
#          max             count        mean  ...       75%    max
# Churn                                       ...
# False  315.6            2850.0  199.043298  ...    233.20  361.8
# True   350.8             483.0  212.410145  ...    249.45  363.7
#
#       Total night minutes                                               \
#                     count        mean        std   min     25%     50%
# Churn
# False              2850.0  200.133193  51.105032  23.2  165.90  200.25
# True                483.0  205.231677  47.132825  47.4  171.25  204.80
#
#
#           75%    max
# Churn
# ...

# %%
data.groupby('Churn')['Account length'].mean()
# Out:
# Churn
# False    100.793684
# True     102.664596
# Name: Account length, dtype: float64

# %%
data.groupby('State').describe()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# 6       MA             121        510                 No             Yes
# 7       MO             147        415                Yes              No
# 8       LA             117        408                 No              No
# 9       WV             141        415                Yes             Yes
# 10      IN              65        415                 No              No
# 11      RI              74        415                 No              No
# ...

# %%
pd.crosstab(data['Churn'], data['International plan'])
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %%
pd.crosstab(data[ data['Churn'] == True]['Churn'], data['State']).max()
# Out:
# State
# AK     3
# AL     8
# AR    11
# AZ     4
# CA     9
# CO     9
# CT    12
# DC     5
# DE     9
# FL     8
# GA     8
# HI     3
# IA     3
# ID     9
# IL     5
# IN     9
# KS    13
# KY     8
# LA     4
# MA    11
# MD    17
# ME    13
# MI    16
# MN    15
# MO     7
# MS    14
# MT    14
# NC    11
# ND     6
# NE     5
# NH     9
# NJ    18
# NM     6
# NV    14
# NY    15
# OH    10
# OK     9
# OR    11
# PA     8
# RI     6
# SC    14
# SD     8
# TN     5
# TX    18
# UT    10
# VA     5
# VT     8
# WA    14
# WI     7
# WV    10
# WY     9
# dtype: int64

# %%
pd.crosstab( data['Churn'], data['State'])
# Out:
# State  AK  AL  AR  AZ  CA  CO  CT  DC  DE  FL ...  SD  TN  TX  UT  VA  VT  WA  \
# Churn                                         ...
# False  49  72  44  60  25  57  62  49  52  55 ...  52  48  54  62  72  65  52
# True    3   8  11   4   9   9  12   5   9   8 ...   8   5  18  10   5   8  14
#
# State  WI  WV  WY
# Churn
# False  71  96  68
# True    7  10   9
#
# [2 rows x 51 columns]

# %%
np.shape( data[data['Churn'] == True ])
# Out:
# (483, 20)

# %%
np.shape( data['State'])
# Out:
# (3333,)

# %%
np.shape((pd.crosstab(data[ data['Churn'] == True]['Churn'], data['State'])))
# Out:
# (1, 51)

# %%
x =pd.crosstab( data['Churn'], data['International plan'])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x)
plt.show()

# %%
pd.crosstab( data['Churn'], data['International plan'])
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %%
pd.crosstab(data['Churn'], data['International plan'])
import seaborn as sns
plt.rcParams['figure.figsize'] = (8,6)
sns.countplot(x='International plan', hue='Churn', data=data);

# %%
pd.crosstab(data['Churn'], data['International plan'])
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,6)
sns.countplot(x='International plan', hue='Churn', data=data);

# %%
x =data['Total day minutes']
plt.hist(x)
plt.show()

# %%
np.max(x)
# Out:
# 350.8

# %%
data[ data['Total day minutes'] < 220][data['Total day minutes'] >160 ]['Churn']
# Out:
# C:\Users\mahidhai\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 1       False
# 4       False
# 6       False
# 8       False
# 11      False
# 16      False
# 17      False
# 18      False
# 22      False
# 26      False
# 28      False
# 32      False
# 34      False
# 38      False
# 41       True
# 46      False
# 47      False
# 50      False
# 52      False
# 53      False
# 55      False
# 57       True
# 60      False
# 62      False
# 63      False
# 68      False
# 69       True
# 73      False
# 78      False
# 79      False
#         ...
# 3242    False
# 3249    False
# 3252    False
# 3254    False
# 3261    False
# 3267    False
# 3269    False
# 3270    False
# 3274    False
# 3277    False
# 3281    False
# 3287     True
# 3289    False
# 3291     True
# 3292    False
# 3296    False
# 3299    False
# 3304     True
# 3307    False
# ...

# %%
plt.hist(x,color='yellow', edgecolor='black',bins = 100)
plt.show()

# %%
for i, binwidth in enumerate([1, 5, 10, 15])
  y = plt.subplot(2, 2, i+1)
  ax.subplot(x ,color = 'orange', edgecolor='black', bins = int(180/binW) )
    
plt.tight_layout()

plt.show()

for i, binwidth in enumerate([1, 5, 10, 15]):
    


for i, binwidth in enumerate([1, 5, 10, 15]):

    

    # Set up the plot

    ax = plt.subplot(2, 2, i + 1)

    

    # Draw the plot

    ax.hist(flights['arr_delay'], bins = int(180/binwidth),

             color = 'blue', edgecolor = 'black')

    

    # Title and labels

    ax.set_title('Histogram with Binwidth = %d' % binwidth, size = 30)

    ax.set_xlabel('Delay (min)', size = 22)

    ax.set_ylabel('Flights', size= 22)



plt.tight_layout()

plt.show()
view raw
different_binwidths.py hosted with ❤ by GitHub

# %%
for i,bin in enumerate([1, 5, 10, 20, 25,30]):
    a = plt.subplot(3,3,i+1)
    a.hist(x,color='orange', edgecolor='black', bins = int(180/bin))
    
    a.set_xlabel(" bin ")
    a.set_ylabel("Number of data points")
    
    
    
    
    

plt.show()

# %%
for i,bin in enumerate([1, 5, 10, 20, 25,30]):
    a = plt.subplot(3,3,i+1)
    a.hist(x,color='orange', edgecolor='black', bins = int(180/bin))
    
    a.set_xlabel(" bin ")
    a.set_ylabel("Number of data points")
    
    
    
    
    
plt.tight_layout()
plt.show()

# %%
#side by side plotting
data.head(1)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                       1  False

# %%
x1 = data[ data['Churn'] == True]['Total day minutes']
x2 = data[ data['Churn'] == True]['Total eve minutes']
x3 = data[ data['Churn'] == True]['Total night minutes']
x4 = data[ data['Churn'] == True]['Total intl minutes']

col = [ 'red', 'yellow' , 'green' , 'blue']

plt.hist([x1,x2,x3,x4], bins =10 ,color = col , edgecolor = 'black' )

plt.show()

# %%
plt.hist([x1,x2,x3,x4], bins =10 ,color = col , edgecolor = 'black', stacked =True )
# Out:
# ([array([ 1., 11., 24., 69., 90., 49., 91., 99., 40.,  9.]),
#   array([  1.,  12.,  34., 107., 180., 177., 203., 174.,  62.,  16.]),
#   array([  1.,  14.,  41., 144., 290., 323., 300., 245.,  73.,  18.]),
#   array([484.,  14.,  41., 144., 290., 323., 300., 245.,  73.,  18.])],
#  array([  0.  ,  36.37,  72.74, 109.11, 145.48, 181.85, 218.22, 254.59,
#         290.96, 327.33, 363.7 ]),
#  <a list of 4 Lists of Patches objects>)

# %%
plt.hist([x1,x2,x3,x4], bins =10 ,color = col , edgecolor = 'black', stacked =True, normed = True )
# Out:
# C:\Users\mahidhai\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ([array([1.42314639e-05, 1.56546103e-04, 3.41555135e-04, 9.81971012e-04,
#          1.28083176e-03, 6.97341733e-04, 1.29506322e-03, 1.40891493e-03,
#          5.69258558e-04, 1.28083176e-04]),
#   array([1.42314639e-05, 1.70777567e-04, 4.83869774e-04, 1.52276664e-03,
#          2.56166351e-03, 2.51896912e-03, 2.88898718e-03, 2.47627473e-03,
#          8.82350765e-04, 2.27703423e-04]),
#   array([1.42314639e-05, 1.99240495e-04, 5.83490022e-04, 2.04933081e-03,
#          4.12712454e-03, 4.59676285e-03, 4.26943918e-03, 3.48670867e-03,
#          1.03889687e-03, 2.56166351e-04]),
#   array([0.00688803, 0.00019924, 0.00058349, 0.00204933, 0.00412712,
#          0.00459676, 0.00426944, 0.00348671, 0.0010389 , 0.00025617])],
# ...

# %%
plt.hist(x2,bins=10)
plt.show()

# %%
#hist for bins 10 for international calls
#so its now 20/2 split
plt.hist(x4)
# Out:
# (array([  1.,  15.,  36.,  89., 120.,  98.,  94.,  18.,  10.,   2.]),
#  array([ 2. ,  3.8,  5.6,  7.4,  9.2, 11. , 12.8, 14.6, 16.4, 18.2, 20. ]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns

sns.distplot(x2, hist=True, kde=True, 
             bins=int(180/18), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
# Out:
# C:\Users\mahidhai\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\mahidhai\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.rugplot(x2)
#these are perpendicular hashes to the ais at each data set

# %%
sns.distplot(x2, hist = True,color = 'red', kde_kws={ 'linewidth' : 3 , 'color' :"red"})
sns.distplot(x3, hist = True, color = 'blue',kde_kws={ 'linewidth' : 1 , 'color' : "blue"})
sns.distplot(x1, hist = True,coor = 'yellow', kde_kws={ 'linewidth' : 2 , 'color' : "yellow"})
# Out:
# C:\Users\mahidhai\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\mahidhai\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\mahidhai\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# ...
